# %%
from ooitk.session import *
session = Session('localhost', 5000)
retrieve(session, dataset_id='559004bfe1f74988aa962d570c8352f5', query={'tdoa':[0,5]})
# Out:
# {u'acc_0824788ff06041d1b0e45508f58ae12f': array([-9999., -9999., -9999., -9999., -9999., -9999., -9999., -9999.,
#        -9999., -9999., -9999., -9999., -9999., -9999., -9999., -9999.,
#        -9999., -9999., -9999., -9999., -9999., -9999., -9999., -9999.,
#        -9999., -9999., -9999., -9999., -9999., -9999., -9999., -9999.,
#        -9999., -9999., -9999., -9999., -9999., -9999., -9999., -9999.]),
#  u'acc_304130b9061b46b5bdf9eb0e04b0337a': array([-9999., -9999., -9999., -9999., -9999., -9999., -9999., -9999.,
#        -9999., -9999., -9999., -9999., -9999., -9999., -9999., -9999.,
#        -9999., -9999., -9999., -9999., -9999., -9999., -9999., -9999.,
#        -9999., -9999., -9999., -9999., -9999., -9999., -9999., -9999.,
#        -9999., -9999., -9999., -9999., -9999., -9999., -9999., -9999.]),
#  u'acc_9f96af5822304329a973f7942469f638': array([-9999., -9999., -9999., -9999., -9999., -9999., -9999., -9999.,
# ...

# %%
response = _

# %%
t0 = response['time'][0]

# %%
t1 = response['time'][10]

# %%
retrieve(session, dataset_id='559004bfe1f74988aa962d570c8352f5', query={'start_time':t0 - 2208988800, 'end_time':t1 - 2208988800})
# Out:
# {u'acc_0824788ff06041d1b0e45508f58ae12f': array([-9999., -9999., -9999., -9999., -9999., -9999.]),
#  u'acc_304130b9061b46b5bdf9eb0e04b0337a': array([-9999., -9999., -9999., -9999., -9999., -9999.]),
#  u'acc_9f96af5822304329a973f7942469f638': array([-9999., -9999., -9999., -9999., -9999., -9999.]),
#  u'acc_e3beba7a32a94ba792c0cdb96700ab1e': array([-9999., -9999., -9999., -9999., -9999., -9999.]),
#  u'acc_f02ee6a273f146e6aa712e90c9a290ef': array([-9999., -9999., -9999., -9999., -9999., -9999.]),
#  u'cmbnflg_qc': array([1, 1, 1, 1, 1, 1], dtype=int8),
#  u'condwat_glblrng_qc': array([-99, -99, -99, -99, -99, -99], dtype=int8),
#  u'condwat_gradtst_qc': array([-99, -99, -99, -99, -99, -99], dtype=int8),
#  u'condwat_loclrng_qc': array([-99, -99, -99, -99, -99, -99], dtype=int8),
#  u'condwat_spketst_qc': array([-99, -99, -99, -99, -99, -99], dtype=int8),
#  u'condwat_stuckvl_qc': array([-99, -99, -99, -99, -99, -99], dtype=int8),
# ...
