# %%
# Make it so notebook knows how to access ooitk from the notebook dir
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))

# %%
from ooitk.session import ERDDAPSession

erddap_url = 'http://erddap-test.oceanobservatories.org:8080/erddap/tabledap/cd6bf968001a464985d12bd2858b3f94.html'

session = ERDDAPSession(erddap_url)
session.open()

# %%
from IPython.display import HTML
s = '<ul>'
for row in session.variables.iterkeys():
    s += '<li>' + str(row) + '</li>'
s += '</ul>'
HTML(s)
# Out:
# <ul><li>amplitude_beam_1</li><li>amplitude_beam_2</li><li>amplitude_beam_3</li><li>analog_input_1</li><li>analog_input_2</li><li>cmbnflg_qc</li><li>correlation_beam_1</li><li>correlation_beam_2</li><li>correlation_beam_3</li><li>driver_timestamp</li><li>eastward_turbulent_velocity</li><li>ensemble_counter</li><li>ingestion_timestamp</li><li>latitude</li><li>longitude</li><li>northward_turbulent_velocity</li><li>port_timestamp</li><li>preferred_timestamp</li><li>seawater_pressure</li><li>time</li><li>turbulent_velocity_east</li><li>turbulent_velocity_north</li><li>turbulent_velocity_vertical</li><li>upward_turbulent_velocity</li><li>velpttu_vle_glblrng_qc</li><li>velpttu_vle_gradtst_qc</li><li>velpttu_vle_loclrng_qc</li><li>velpttu_vle_spketst_qc</li><li>velpttu_vle_stuckvl_qc</li><li>velpttu_vle_trndtst_qc</li><li>velpttu_vln_glblrng_qc</li><li>velpttu_vln_gradtst_qc</li><li>velpttu_vln_loclrng_qc</li><li>velpttu_vln_spketst_qc</li><li>velpttu_vln_stuckvl_qc</li><li>velpttu_vln_trndtst_qc</li><li>velpttu_vlu_glblrng_qc</li><li>velpttu_vlu_gradtst_qc</li><li>velpttu_vlu_loclrng_qc</li><li>velpttu_vlu_spketst_qc</li><li>velpttu_vlu_stuckvl_qc</li><li>velpttu_vlu_trndtst_qc</li></ul>

# %%
time = session.variables['time'][:]
beam1 = session.variables['amplitude_beam_1'][:]

# %%
session.variables['amplitude_beam_1'].units
# Out:
# u'counts'

# %% [markdown]
# ## Time to plot some variables

# %%
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
ax = plt.subplot(111)
ax.set_title('VEL3D')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Amplitude (%s)' % str(session.variables['amplitude_beam_1'].units))

ax.plot(time, beam1, color='g')

plt.show()

# %%
lat = session.variables['latitude'][:]
# Out:
# masked_array(data = [--],
#              mask = [ True],
#        fill_value = )

# %%
session.close()
